# %%
import helper
from helper import *
import importlib
importlib.reload(helper)

df = load_merged_data(only_standard_refuelling=False, drop_na=False)

# %%
from pandas.plotting import lag_plot

lag_plot(df['bufferChargingDegree'], lag=6 * 10)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 60)'>
