# %% [markdown]
# # Auswahl einer geeigneten Python Bibliothek zur Visualisierung der EDA
#
# Es gibt eine Vielzahl an Aspekten, die bei der Auswahl einer geeigneten Visualisierungs-Bibliothek für Python berücksichtigt werden sollten. Dazu zählen unter anderem die Intuitive Verwendung, die Größe des vorliegenden Datensatzes, Individualisierungsmöglichkeiten oder die  generelle Integration mit dem Python Ökosystem. Nach Untersuchung dieser Aspekte kann ebenfalls entschieden werden, ob eine Hochschicht-API für den vorliegenden Anwendungsfall ausreichend ist, oder bspw. die hohe Flexibilität und Anpassbarkeit einer Kern-Bibliothek notwendig ist. Für den vorliegenden Anwendungsfall, in dem der optimale Nachfüllzeitpunkt für einen Holzvergaser anhand einer Zeitreihenanalyse ermittelt werden soll, wird die seaborn Bibliothek für die Visualisierung der zugrunde liegenden Daten und der späteren Analyseergebnisse verwendet. Da seaborn als Hochshcicht-API nahtlos auf der Kern-Bibliothek matplotlib aufbaut, kann diese, wenn nötig, ebenfalls zur Anpassung der mit seaborn erzeugten Grafiken verwendet werden.
#
# Ein Überblick der vorhandenen Bibliotheken zur Datenvisualisierung in Python zeigt, dass es sich bei seaborn und matplotlib auch um die gängigsten Visualisierungsbibliotheken handelt, wenn es darum geht, statistische Anwendungsfälle darzustellen.
#
# [Python Bibliotheken zur Datenvisualisierung](https://pyviz-tutorial.readthedocs.io/de/latest/overview.html)

# %% [markdown]
# # Gegenüberstellung matplotlib und seaborn
#
# Matplotlib wurde hauptsächlich für grundlegende Visualisierung von Daten entwickelt. Die Bibliothek beinhaltet daher grundlegende Diagrammtypen, wie Balken-, Torten-, Linien-, Punkt- bzw. Streudiagramme. Seaborn hingegen bietet eine Vielzahl von Visualisierungsmöglichkeiten bei reduzierter Syntax und optisch ansprechenderen Standardgrafiken. Der Fokus von seaborn liegt dabei auf der Erstellung von statistischen Grafiken. Zusätzlich bietet Seaborn die bessere Integrität mit den Datenrahmen der pandas Bibliothek, die ebenfalls im Bereich der Datenvorverarbeitung dieser Hausarbeit zum Einsatz kommt. In punkto Flexibilität ist matplotlib in hohem Maße anpassbar und leistungsstark und bietet somit im Vergleich zu seaborn einen Vorteil, wenn es um die Individualisierung der Grafiken geht. Je höher jedoch der Individualisierungsgrad der Grafik, desto höher ist ebenso die Komplexität, die bei der Erzeugung der Grafik an den Tag gelegt werden muss. Da seaborn jedoch als Hochschicht API auf matplotlib aufsetzt, kann jede mit seaborn erstellte Grafik ebenso unter Zuhilfenahme der matplotlib Funktionalitäten weiter angepasst werden.
#
# [Gegenüberstellung matplotlib und seaborn](https://medium.com/analytics-vidhya/introduction-to-matplotlib-and-seaborn-e2dd04bfc821#:~:text=Matplotlib%3A%20Matplotlib%20is%20mainly%20deployed,has%20easily%20interesting%20default%20themes)
#
# Für die vorliegende Hausarbeit wird hauptsächlich die seaborn Bibliothek verwendet, da diese auf Visualisierung statistischer Anwendungsfälle ausgelegt ist, bspw. die Durchführung einer explorativen Datenanalyse. Zudem ist die Anwendung durch die vereinfachte Syntax intuitiver als bei matplotlib. Durch die Vielzahl an bereits vorhandenen Standards in Bezug auf Farbthemen oder Diagrammtypen, bietet seaborn dennoch ausreichend Funktionalität, um alle anfallenden Visualisierungsanforderungen in dieser Arbeit abzudecken. Sollten dennoch individuelle Anpassungen der Grafiken notwendig sein, die durch seaborn nicht realisiert werden können, dann ist durch die nahtlose Integration mit matplotlib eine einfache Weiterverarbeitung der Grafiken sichergestellt.

# %% [markdown]
# # Was ist seaborn?
#
# Seaborn ist eine Bibliothek zur Erstellung statistischer Grafiken in Python. Sie baut auf matplotlib auf und ist eng mit den Datenstrukturen von pandas integriert.
# Seaborn hilft Ihnen beim Erforschen und Verstehen Ihrer Daten. Die Plotting-Funktionen arbeiten mit Dataframes und Arrays, die ganze Datensätze enthalten, und führen intern das notwendige semantische Mapping und die statistische Aggregation durch, um informative Plots zu erstellen. Die datensatzorientierte, deklarative API ermöglicht es Ihnen, sich auf die Bedeutung der verschiedenen Elemente Ihrer Diagramme zu konzentrieren und nicht auf die Details, wie sie zu zeichnen sind.
#
# [seborn](https://seaborn.pydata.org/tutorial/introduction.html)

# %% [markdown]
# # Was ist eine explorative Datenanalyse (EDA)?
#
# Die in den 1970er Jahren von dem amerikanischen Mathematiker John Turkey eingeführte explorative Datenanalyse (EDA) ist eine Methodik zur umfassenden Untersuchung von Datensätzen, die auch heute noch allgegenwertig ist. Hauptaugenmerk liegt hierbei auf der Herausstellung und Zusammenfassung grundlegender Eigenschaften des Datensatzes. Dazu zählen Trends, Muster und Beziehungen, die nicht ohne weiteres erkennbar sind. Damit diese Eigenschaften leichter zu erkennen sind, wird häufig auf Datenvisualisierungstechniken zurückgegriffen.
#
# Die EDA führt zu einem besseren Verständnis der Variablen, aus denen der Datensatz besteht, und verdeutlicht die Zusammenhänge zwischen ihnen. Darüber hinaus kann die EDA Aufschluss darüber geben, welche statistischen Methoden für die weitergehende Datenanalyse geeignet sein können.
#
# [Explorative Datenanalyse](https://www.ibm.com/de-de/topics/exploratory-data-analysis)

# %% [markdown]
# # Warum ist eine EDA wichtig in der Datenwissenschaft?
#
# Es soll zunächst ein erstes Verständnis für die Merkmale eines Datensatzes geschaffen werden. Die EDA gibt einen Überblick über die Verteilung, die zentralen Tendenzen und die Schwankungen der Daten und bietet Einblicke in die Natur der vorliegenden Informationen. Zusätzlich können Datenwissenschaftler mittels einer EDA Muster, Trends und Unregelmäßigkeiten in den Daten erkennen. Dies hilft bei der Erkennung von Anomalien oder Ausreißern, die beispielsweise auf Probleme mit der Datenqualität hinweisen oder einzigartige Einblicke bieten können. Anhand einer EDA lassen sich zudem auch leichter Hypothesen über die Beziehungen und Trends in den Daten aufstellen, welche in der anschließenden statistischen Analyse formell getestet werden können.

# %% [markdown]
# # Welche Arten der EDA gibt es?
#
# Grundlegend kann eine explorative Datenanalyse auf 2 Arten durchgeführt werden. Quantitativ durch beschreibende Statistik oder durch grafische Aufbereitung der Daten. In dieser Arbeit steht die visuelle Aufbereitung der Daten im Fokus und wird im Folgenden näher erläutert. Bei der grafischen EDA wird zwischen der univariaten Analyse und der multivariaten Analyse unterschieden. Die univariate Analyse fokussiert lediglich eine Variable des Datensatzes zur Zeit. Für kategorische Variablen bieten sich daher Balkendiagramme mit der absoluten Häufigkeit der einzelnen Kategorien an, oder Tortendiagramme, die zusätzliche eine prozentuale Verteilung der einzelnen Kategorien der zu untersuchenden Variable darstellen können. Handelt es sich hingegen um eine numerische Variable, die untersucht werden soll so kann beispielsweise ein Histogramm Aufschluss über die Verteilung der Daten gegeben. Einen ähnlichen Einblick bietet, basierend auf einem Histogramm, eine zusätzliche Dichteverteilung in Form einer Kurve über dem Histogramm. Eine andere Art, die Verteilung innerhalb der Daten zu visualisieren, bietet ein Boxplot Diagramm. Es gibt bspw. Aufschluss über Minimal- und Maximalwerte, Quantile, den Mittelwert bzw. Median der Daten und es unterstützt visuell bei der Erkennung von möglichen Ausreißen in den Daten. Ähnlich zum Boxplot Diagramm, kann auch ein Violinen Diagramm zur Darstellung der Verteilung der Daten verwendet werden.
# Im Gegensatz zur univariaten Analyse befasst sich die multivariate Analyse mit mindestens 2 Variablen zur selben Zeit. Es kann nun also bspw. die Korrelation der Variablen untersucht werden. Auch hier gibt es wieder unterschiedliche Darstellungsmöglichkeiten, je nachdem, ob es sich um kategorische oder numerische Variablen handelt. Hinzu kommt, dass auch Kombinationen aus kategorischen und numerischen Variablen untersucht werden können.
# Für die weiteren Erläuterungen wird sich auf die bivariate Analyse als Spezialfall der multivariaten Analyse fokussiert, wo lediglich 2 Variablen zu gleichen Zeit untersucht werden. Es ergeben sich somit die folgenden 3 Kombinationen, die berücksichtigt werden müssen.
# Zunächst sollen zwei numerische Variablen miteinander verglichen werden. Eines der gängigsten Diagramme für diesen Anwendungsfall ist das Streudiagramm, welches den Schnittpunkt zwischen den beiden Variablen als Punkt in einem 2-dimensionalen Koordinatensystem mit den beiden Variablen als X- bzw. als Y-Achse abbildet.
# Soll die Beziehung zwischen einer numerischen und einer kategorischen Variable dargestellt werden, so bietet sich ein klassisches Balkendiagramm an. Jeder Balken repräsentiert eine Ausprägung der kategorischen Variable und die Länge bzw. Höhe des Balkens repräsentiert den zugehörigen Wert der numerischen Variable zu dieser Kategorie.
# Abschließend wird noch die Beziehung zwischen zwei kategorischen Variablen beschrieben. In diesem Fall ist eine gängige Visualisierungsmöglichkeit, die Gegenüberstellung der beiden Variablen in einer Heatmap. Hier wird die Korrelation der beiden Variablen anhand einer Farbskala dargestellt.
#
# [Visualisierungstechniken für die EDA](https://towardsdatascience.com/an-overview-of-visual-techniques-for-exploratory-data-analysis-in-python-d35703d43faf)

# %% [markdown]
# Zunächst wird zum besseren Verständnis exemplarisch ein Überblick über die Daten gegeben. Dafür wird in der folgenden Visualisierung der Zeitraum vom 10-01-2023 bis zum 20-01-2023 betrachtet. Dargestellt wird der Ladezustand des Pufferspeichers in Abhängigkeit von der Zeit. Daran ist direkt zu erkennen, dass bei positiver Steigung der Puffer Energie aufnimmt und daher der Ofen brennt. Bei negativer Steigung gibt der Puffer Energie ab.
#
# Zusätzlich sind die tatsächlichen spätesten Nachfüllzeitpunkte als vertikale Linien eingezeichnet. Diese Zeitpunkte sollen vorhergesagt werden (bzw. die Dauer, bis der Zeitpunkt erreicht wird). Der Puffer ladegrad ist jeweils in der Farbe dargestellt, in der auch der zugehörige Nachfüllzeitpunkt eingezeichnet ist. Hier wird noch einmal deutlich, dass dies nicht immer der nächste Nachfüllzeitpunkt ist, da der Ofen bereits mit neuem Holz befüllt sein kann und der Ofen automatisch wieder zündet, wenn der Puffer leer ist (= 15 % hat).
#
# Lücken in den Daten entstehen, wenn der tatsächliche späteste Nachfüllzeitpunkt nicht ermittelt werden kann. Dies ist der Fall, wenn der Ofen vorzeitig manuell gezündet wird und somit der Puffer nie 15 % erreicht.

# %%
import helper
from helper import *
import importlib
importlib.reload(helper)
import matplotlib.pyplot as plt
import seaborn as sns

df = load_merged_data(only_standard_refuelling=True)

# %%
from datetime import datetime


start_date = datetime(2023, 1, 10)
end_date = datetime(2023, 1, 20)

display_df = df.loc[(df['date'] >= start_date) & (df['date'] <= end_date)]

color_palette_name = 'tab20'

fig, ax = plt.subplots(figsize=(15, 5))
sns.scatterplot(data=display_df, x="date", y="bufferChargingDegree", ax=ax, label="bufferChargingDegree", linewidth=0, hue='refuellingDateActual', palette=color_palette_name)

# find all unique refuelling dates
refuelling_dates = display_df['refuellingDateActual'].unique()

# remove null
refuelling_dates = refuelling_dates[~pd.isnull(refuelling_dates)]

for index, refuelling_date in enumerate(refuelling_dates):
    # get color from palette
    color_palette = sns.color_palette(color_palette_name)
    color = color_palette[index % len(color_palette)]
    ax.axvline(refuelling_date, linestyle='-.', color=color)
    
# add a horizontal line at y = 15
ax.axhline(15, color='black', linestyle='--')

# hide the legend
ax.legend().remove()

# %% [markdown]
# # Explorative Datenanalyse des Holsvergaser-Ofens
#
# Zu Beginn der EDA wird zunächst der zugrundeliegende Datensatz der Arbeit geladen und grundlegende Informationen zum Datensatz unter Zuhilfenahme der funktionen info() und shape der pandas Bibliothek abgerufen. Zudem werden exemplarisch 50 Zeilen des Datensatzes ausgegeben.

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7756472 entries, 913 to 10045578
# Data columns (total 57 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   date                            datetime64[ns]
#  1   refuellingQuantity              float64
#  2   refuellingTimePoint             float64
#  3   prematureRefuellingCount        float64
#  4   operationPhase                  object
#  5   bufferChargingDegree            float64
#  6   refuellingDateActual            datetime64[ns]
#  7   refuellingChargingDegreeActual  float64
#  8   refuellingTimePointActual       float64
#  9   Year sin                        float64
#  10  Year cos                        float64
#  11  Anheizen                        float64
#  12  Anzünden                        float64
#  13  Ausbrennen                      float64
#  14  Ausgeschaltet                   float64
#  15  Automatik                       float64
# ...

# %%
df.head(50)
# Out:
#                    date  refuellingQuantity  refuellingTimePoint  \
# 913 2019-11-13 10:32:10                 0.0            42.450000
# 914 2019-11-13 10:32:20                 0.0            42.450000
# 915 2019-11-13 10:32:30                 0.0            42.450000
# 916 2019-11-13 10:32:40                 0.0            42.450000
# 917 2019-11-13 10:32:50                 0.0            42.450000
# 918 2019-11-13 10:33:00                 0.0            42.450000
# 919 2019-11-13 10:33:10                 0.0            42.433333
# 920 2019-11-13 10:33:20                 0.0            42.433333
# 921 2019-11-13 10:33:30                 0.0            42.433333
# 922 2019-11-13 10:33:40                 0.0            42.433333
# 923 2019-11-13 10:33:50                 0.0            42.433333
# 924 2019-11-13 10:34:00                 0.0            42.433333
# 925 2019-11-13 10:34:10                 0.0            42.416667
# ...

# %% [markdown]
# Es ist festzuhalten, dass der Datensatz insgesamt aus 57 unterschiedlichen Attributen und insgesamt 7.756.472 Datensätzen besteht. Bei 54 Attributen des Datensatzes handelt es sich um numerische Attribute. Die Variablen 'date' und 'refuellingDateActual' liegen im Datumsformat vor und mit dem Attribut 'operationPhase' gibt es genau ein kategorisches Attribut für den Zustand des Holzvergaser-Ofens im Datensatz.

# %% [markdown]
# # Univariate Untersuchung numerischer Attribute
# Im Folgenden werden die numerischen Attribute des Datensatzes im einzelnen näher betrachtet. Hierzu werden beispielsweise Mittelwerte, Minimal- und Maximalwerte und auch die 0,25/0,5/0,75 Quantile begutachtet, um einen ersten Eindruck über die Verteilung der Werte innerhalb der einzelnen Attribute zu erhalten. Der Fokus liegt hierbei auf den Attributen 'refuellingQuantity', 'refuellingTimePoint', 'prematureRefuellingCount', 'bufferChargingDegree', 'weatherTemperature' und 'refuellingTimePointActual', da die meisten der weiteren Attribute lediglich Zeitlich verschobene Werte der genannten Attribute darstellen, wie im Abschnitt data_preparation näher erläutert. Somit würden sie die gleiche Verteilung der Werte ausweisen und im Vergleich zu den Fokus Attributen keine neuen Erkenntnisse aufzeigen.

# %%
df.describe().transpose()
# Out:
#                                     count                           mean  \
# date                              7756472  2021-07-10 05:45:19.283137536
# refuellingQuantity              7756472.0                      26.792778
# refuellingTimePoint             7756472.0                      22.753543
# prematureRefuellingCount        7756472.0                     535.738851
# bufferChargingDegree            7756472.0                      46.898102
# refuellingDateActual              7756472  2021-07-11 03:26:37.046372864
# refuellingChargingDegreeActual  7756472.0                      14.998133
# refuellingTimePointActual       7756472.0                      21.688268
# Year sin                        7756472.0                      -0.047119
# Year cos                        7756472.0                      -0.002187
# Anheizen                        7756472.0                            0.0
# Anzünden                        7756472.0                            0.0
# ...

# %% [markdown]
# Zur übersichtlicheren Darstellung der Werte für die numerischen Attribute werden Boxplot Diagramme erzeugt. Dieser Diagrammtyp visualisiert die zuvor erzeugen Werte und erleichtert somit den Einblick in die Daten.

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 8))

# Plot histograms in each plot
sns.boxplot(data=df, x='refuellingQuantity', ax=axes[0, 0]).set(xlabel='Refuelling Quantity (stove)')
sns.boxplot(data=df, x='refuellingTimePoint', ax=axes[0, 1]).set(xlabel='Refuelling Time Point')
sns.boxplot(data=df, x='prematureRefuellingCount', ax=axes[0, 2]).set(xlabel='Premature Refuelling Count')
sns.boxplot(data=df, x='bufferChargingDegree', ax=axes[1, 0]).set(xlabel='Buffer Charging Degree')
sns.boxplot(data=df, x='refuellingTimePointActual', ax=axes[1, 1]).set(xlabel='Refuelling Time Point Actual')
sns.boxplot(data=df, x='weatherTemperature', ax=axes[1, 2]).set(xlabel='Outside Temperature (Weather data)')

# Adjust space between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Durch Auswertung der Boxplot Diagramme ist festzustellen, dass besonders die Attribute für die Zeit bis zum nächsten Nachfüllen ('refuellingTimePoint') und der tatsächliche ermittelte Zeitpunkt bis zum nächsten Nachfüllen ('refuellingTimePointActual') weit gestreute Außreißer in positiver Richtung aufweisen.

# %%
# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 8))

# Plot histograms in each plot
sns.violinplot(data=df, x='refuellingQuantity', ax=axes[0, 0]).set(xlabel='Refuelling Quantity')
sns.violinplot(data=df, x='refuellingTimePoint', ax=axes[0, 1]).set(xlabel='Refuelling Time Point')
sns.violinplot(data=df, x='bufferChargingDegree', ax=axes[0, 2]).set(xlabel='Buffer Charging Degree')
sns.violinplot(data=df, x='prematureRefuellingCount', ax=axes[1, 0]).set(xlabel='Premature Refuelling Count')
sns.violinplot(data=df, x='refuellingTimePointActual', ax=axes[1, 1]).set(xlabel='Refuelling Time Point Actual')
sns.violinplot(data=df, x='weatherTemperature', ax=axes[1, 2]).set(xlabel='Outside Temperature (Weather data)')

# Adjust space between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 8))

# Plot histograms in each plot
sns.histplot(data=df, x='refuellingQuantity', kde=False, bins=10, ax=axes[0, 0]).set(xlabel='Refuelling Quantity')
sns.histplot(data=df, x='refuellingTimePoint', kde=False, bins=20, ax=axes[0, 1]).set(xlabel='Refuelling Time Point')
sns.histplot(data=df, x='bufferChargingDegree', kde=False, bins=20, ax=axes[0, 2]).set(xlabel='Buffer Charging Degree')
sns.histplot(data=df, x='prematureRefuellingCount', kde=False, bins=20, ax=axes[1, 0]).set(xlabel='Premature Refuelling Count')
sns.histplot(data=df, x='refuellingTimePointActual', kde=False, bins=20, ax=axes[1, 1]).set(xlabel='Refuelling Time Point Actual')
sns.histplot(data=df, x='weatherTemperature', kde=False, bins=20, ax=axes[1, 2]).set(xlabel='Outside Temperature (Weather data)')

# Adjust space between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Univariate Untersuchung kategorischer Attribute
# Da es lediglich ein kategorisches Attribut in dem Datensatz gibt, wird im Folgenden die Verteilung der einzelnen Operationszustände des Ofens visuell aufbereitet. Zur Darstellung der Mächtigkeit der unterschiedlichen Kategorien wird ein einfaches Balkendiagramm verwendet, dass auf der X-Achse die einzelnen Zustände des Ofen repräsentiert, auf der Y-Achse ist die Anzahl aufgeführt. Ein Tortendiagramm wird verwendet, um Einblick in die prozentuale Verteilung über die Kategorien hinweg zu erhalten.

# %%
sns.countplot(data=df, x='operationPhase').set(xlabel='Operation Phase', ylabel='Count')
# Out:
# [Text(0.5, 0, 'Operation Phase'), Text(0, 0.5, 'Count')]

# %%
values = df['operationPhase'].value_counts()
plt.figure(figsize=(6,6))
values.plot(kind='pie',fontsize=17, autopct='%.2f')
plt.legend(labels=values.index, loc="best")
plt.show()

# %% [markdown]
# # Mulitvariate Untersuchung der Daten

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms in each plot
sns.boxplot(data=df, x='refuellingQuantity', y='operationPhase', ax=axes[0, 0]).set(xlabel='Refuelling Quantity', ylabel='Operation Phase')
sns.boxplot(data=df, x='refuellingTimePoint', y='operationPhase', ax=axes[0, 1]).set(xlabel='Refuelling Time Point', ylabel='Operation Phase')
sns.boxplot(data=df, x='bufferChargingDegree', y='operationPhase', ax=axes[1, 0]).set(xlabel='Buffer Charging Degree', ylabel='Operation Phase')
sns.boxplot(data=df, x='prematureRefuellingCount', y='operationPhase', ax=axes[1, 1]).set(xlabel='Premature Refuelling Count', ylabel='Operation Phase')

# Adjust space between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms in each plot
sns.histplot(data=df, x='refuellingQuantity', kde=False, bins=40, hue='operationPhase', ax=axes[0, 0]).set(xlabel='Refuelling Quantity', ylabel='Count')
sns.histplot(data=df, x='refuellingTimePoint', kde=False, bins=40, hue='operationPhase', ax=axes[0, 1]).set(xlabel='Refuelling Time Point', ylabel='Count')
sns.histplot(data=df, x='bufferChargingDegree', kde=False, bins=40, hue='operationPhase', ax=axes[1, 0]).set(xlabel='Buffer Charging Degree', ylabel='Count')
sns.histplot(data=df, x='prematureRefuellingCount', kde=False, bins=40, hue='operationPhase', ax=axes[1, 1]).set(xlabel='Premature Refuelling Count', ylabel='Count')

# Adjust space between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
selected_columns = ['refuellingQuantity', 'refuellingTimePoint', 'bufferChargingDegree', 'prematureRefuellingCount', 'operationPhase']
small_df = df[selected_columns]
small_df_100th_row = small_df.iloc[::10000]
sns.pairplot(data=small_df_100th_row, hue='operationPhase')
# Out:
# C:\Users\gleehr\holzofen-machine-learning\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Untersuchung der Daten auf Autokorrelation

# %%
from datetime import datetime
from statsmodels.tsa.seasonal import seasonal_decompose

start_date = datetime(2022, 1, 1)
end_date = datetime(2022, 12, 31)

display_df = df.loc[(df['date'] >= start_date) & (df['date'] <= end_date)]
display_df_5000th_row = display_df.iloc[::5000]

#Definiere Attribute, die untersucht werden sollen
attr_to_examine = ['refuellingQuantity', 'refuellingTimePoint', 'bufferChargingDegree', 'prematureRefuellingCount', 'refuellingTimePointActual', 'weatherTemperature']

#Definiere Labels für die Attribute
labels = ['Refuelling Quantity', 'Refuelling Time Point', 'Buffer Charging Degree', 'Premature Refuelling Count', 'Refuelling Time Point Actual', 'Weather Temperature']

for attr, label in zip(attr_to_examine, labels):
    result = seasonal_decompose(display_df_5000th_row[attr], model='additive', period=12)
    result.plot()
    plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

#Wähle nur jeden hundertsten Datenatz
df_100th_row = df.iloc[::100]

# Create a 2x6 grid of subplots
fig, axes = plt.subplots(nrows=6, ncols=2, figsize=(15, 35))

#Hilfsvariable für die Subplots
var_axes_acf = [((0,0), (0,1)), ((1,0), (1,1)), ((2,0), (2,1)), ((3,0), (3,1)), ((4,0), (4,1)), ((5,0), (5,1))]

for attr, label, axx in zip(attr_to_examine, labels, var_axes_acf):
    plot_acf(df_100th_row[attr], ax=axes[axx[0]])
    plot_pacf(df_100th_row[attr], ax=axes[axx[1]])
    axes[axx[0]].set_title('ACF: ' + label)
    axes[axx[1]].set_title('PACF: ' + label)

fig.suptitle('Autokorrelation Plots ausgewählter Attribute', fontsize=16)

plt.tight_layout()

plt.show()

# %%
from pandas.plotting import lag_plot

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 20))

#Hilfsvariable für die Subplots
var_axes_lag = [(0,0), (0,1), (1,0), (1,1), (2,0), (2,1)]

for attr, axx in zip(attr_to_examine, var_axes_lag):
    lag_plot(df_100th_row[attr], lag=10, ax=axes[axx])
    axes[axx].set_title(f'Lag Plot (Attribut={attr})')
    
    
plt.show()

# %%
#Berechnung der prozentualen Abweichung der prognostizierten Dauer bis zum nächsten Nachfüllen von der tatsächlichen Dauer 
df['refuellingTimePointDeviation'] = (1 - (df['refuellingTimePoint'] / df['refuellingTimePointActual'])) * 100
#df.head(50)
#df.describe().transpose()
sns.histplot(data=df, x='refuellingTimePointDeviation', kde=True, bins=300)
# Out:
# <Axes: xlabel='refuellingTimePointDeviation', ylabel='Count'>
